# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                      talnakh  69.4865   88.3972    -12.66
# 1        1                fort st. john  56.2499 -120.8529      6.94
# 2        2                    sharypovo  55.5403   89.2008      1.25
# 3        3                        khovd  48.0056   91.6419     -1.22
# 4        4  edinburgh of the seven seas -37.0676  -12.3116     15.37
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        95         100        3.19      RU  1700278364
# 1        65          75        5.66      CA  1700278364
# 2        91         100        3.13      RU  1700278365
# 3        68          92        0.74      MN  1700278365
# 4        91          91       10.97      SH  1700278365

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600    
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
# Narrow down cities that fit criteria and drop any results with null values
#A max temperature lower than 27 degrees but higher than 21
#Wind speed less than 4.5 m/s
#Zero cloudiness
preferred_cities_df = pd.DataFrame(city_data_df.loc[(city_data_df['Max Temp'] > 21) &
                                                     (city_data_df['Max Temp'] < 27) &
                                                     (city_data_df['Wind Speed'] < 4.5) &
                                                     (city_data_df['Cloudiness'] == 0)])

# Drop any rows with null values


# Display sample data
len(preferred_cities_df)
# Out:
# 9

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = preferred_cities_df[['City','Country','Lat','Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#                 City Country      Lat      Lng  Humidity Hotel Name
# 21             nohar      IN  29.1833  74.7667        29
# 57      saint-pierre      RE -21.3393  55.4781        73
# 98              tete      MZ -16.1564  33.5867        57
# 184          ondjiva      AO -17.0667  15.7333        69
# 235  nieuw amsterdam      SR   5.8833 -55.0833        88

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set the parameters for the type of search
limit = 1
radius = 10000

# set up a parameters dictionary
params = {
    "categories":"accommodation.hotel",
    "limit":10,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = hotel_df.loc[index, 'Lng']
    latitude = hotel_df.loc[index, 'Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filters"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Make an API request using the params dictionaty
    name_address = requests.get(query_url)
    
    # Convert the API response to JSON format
    name_json = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_json["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# nohar - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# tete - nearest hotel: Zambezi Hotel
# ondjiva - nearest hotel: Águia Verde Hotel
# nieuw amsterdam - nearest hotel: Leonsberg Lodge
# dwarka - nearest hotel: The Dwarika Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# matozinhos - nearest hotel: No hotel found
# bariarpur - nearest hotel: No hotel found
#                 City Country      Lat      Lng  Humidity         Hotel Name
# 21             nohar      IN  29.1833  74.7667        29     No hotel found
# 57      saint-pierre      RE -21.3393  55.4781        73       Tropic Hotel
# 98              tete      MZ -16.1564  33.5867        57      Zambezi Hotel
# 184          ondjiva      AO -17.0667  15.7333        69  Águia Verde Hotel
# 235  nieuw amsterdam      SR   5.8833 -55.0833        88    Leonsberg Lodge
# 307           dwarka      IN  22.2394  68.9678        47  The Dwarika Hotel
# 325  remire-montjoly      GF   4.9167 -52.2667        94    Complexe Belova
# 510       matozinhos      BR -19.5578 -44.0814        57     No hotel found
# 555        bariarpur      IN  25.3000  86.5833        64     No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map
map_plot_1 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    hover_cols=['City','Country']
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Country)
